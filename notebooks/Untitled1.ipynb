# %% [markdown]
# JUSNOOR KAUR SACHDEVA
#
# I am interested in knowing about the operator causing the maximum number of fatalities so that the required safety measures can be implemented.
#
#
# Task-1 Exploratory Data Analysis

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
#Loading the dataset

file='/Users/jusnoorkaursachdeva/Desktop/school/year1/summer/cosc301/project-group46/data/processed/COSC301_dataset - Sheet1.csv'
data=pd.read_csv(file)
data
# Out:
#                                                  date   time  \
# 0                                          01/03/2004   4:44
# 1                                          01/13/2004  19:40
# 2                                          01/17/2004  16:40
# 3                                          01/28/2004  20:55
# 4                                          02/06/2004   8:01
# ..                                                ...    ...
# 599                                        05/26/2009    NaN
# 600                                        06/01/2009   0:15
# 601                                        06/07/2009   8:30
# 602  >>>>>>> ea9cce248f81730041f8858938a0313971237052    NaN
# 603                                        06/08/2009    NaN
#
#                                               Location  \
# 0                           Off Sharm el Sheikh, Egypt
# 1                                 Tashkent, Uzbekistan
# 2         Lake Erie, off Pelee Island, Ontario, Canada
# ...

# %%
data.describe()
# Out:
#               date   time      Location                         Operator  \
# count          604    565           598                              600
# unique         285    192           292                              287
# top     01/13/2005  11:00  Tehran, Iran  Military - Indonesian Air Force
# freq             6     14             6                                6
#
#            route                       type registeration Aboard Fatilities  \
# count        566                        600           565    602        602
# unique       272                        246           283     83         68
# top     Training  Cessna 208B Grand Caravan        N195GA      2          2
# freq          12                         18             2     58         66
#
#        Ground
# count     600
# unique     12
# top         0
# freq      561

# %%
#error message

# %%
data.shape
# Out:
# (604, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           604 non-null    object
#  1   time           565 non-null    object
#  2   Location       598 non-null    object
#  3   Operator       600 non-null    object
#  4   route          566 non-null    object
#  5   type           600 non-null    object
#  6   registeration  565 non-null    object
#  7   Aboard         602 non-null    object
#  8   Fatilities     602 non-null    object
#  9   Ground         600 non-null    object
# dtypes: object(10)
# memory usage: 47.3+ KB

# %%
data.head()
# Out:
#          date   time                                      Location  \
# 0  01/03/2004   4:44                    Off Sharm el Sheikh, Egypt
# 1  01/13/2004  19:40                          Tashkent, Uzbekistan
# 2  01/17/2004  16:40  Lake Erie, off Pelee Island, Ontario, Canada
# 3  01/28/2004  20:55                             Ghardaïa, Algeria
# 4  02/06/2004   8:01                   Bitonja, Bosnia-Herzegovina
#
#                              Operator  \
# 0                           Flash Air
# 1                  Uzbekistan Airways
# 2                     Georgia Express
# 3                    Tassili Airlines
# 4  Military - Government of Macedonia
#
#                                       route                           type  \
# 0     Sharm el Sheikh, Egypt - Cairo, Egypt               Boeing B-737-3Q8
# 1                         Termez - Tashkent                Yakovlev YAK-40
# 2  Pelee Island, Ontario - Windsor, Ontario      Cessna 208B Grand Caravan
# ...

# %%
data.columns
# Out:
# Index(['date', 'time', 'Location', 'Operator', 'route', 'type',
#        'registeration', 'Aboard', 'Fatilities', 'Ground'],
#       dtype='object')

# %%
#to find the unique values for different variables
data.nunique(axis=0)
# Out:
# date             285
# time             192
# Location         292
# Operator         287
# route            272
# type             246
# registeration    283
# Aboard            83
# Fatilities        68
# Ground            12
# dtype: int64

# %%
data.operator.unique    #error due to wrong name of attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9q/009gn4wx6wsf1xc5ktg2_tch0000gn/T/ipykernel_74557/1586689524.py in <module>
# ----> 1 data.operator.unique    #error due to wrong name of attribute
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'operator'

# %%
data.operator.unique()  #error due to wrong name of attribute

# %%
df.Operator.unique()

# %%
data.Operator.unique()

# %%
data.Location.unique()

# %%
data.date.unique()

# %%
data.type.unique()

# %%
BEGINNING OF EDA:

Using the guide 2 EDA template given on milestone 3 page for a thorough analysis

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

def eda(dframe):
    # check that input is pandas dataframe
    if type(dframe) != pd.core.frame.DataFrame:
        raise TypeError("Only pandas dataframe is allowed as input")
        
    # replace field that's entirely space (or empty) with NaN
    data = dframe.replace(r'^\s*$', np.nan, regex=True)

    print("Preview of data:")
    display(dframe.head(3))

    print("\nTo check: \n (1) Total number of entries \n (2) Column types \n (3) Any null values\n")
    print(dframe.info())

    # generate preview of entries with null values
    if dframe.isnull().any(axis=None):
        print("\nPreview of data with null values:")
        display(dframe[dframe.isnull().any(axis=1)].head(3))
        
        plt.show()

    # generate count statistics of duplicate entries
    if len(data[data.duplicated()]) > 0:
        print("\nNumber of duplicated entries: ", len(data[data.duplicated()]))
        display(data[data.duplicated(keep=False)].sort_values(by=list(data.columns)).head())
    else:
        print("\nNo duplicated entries found")

# %%
eda(dframe) #error due to wrong variable used

# %%
eda(df)

# %%
eda(data)

# %%
sns.jointplot(data=data,x='Fatilities',y='Aboard',height=20)
