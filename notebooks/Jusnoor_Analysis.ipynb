# %% [markdown]
# TASK 4 : DATA ANALYSIS
#
# My aim through this analysis is to find out that which operator caused the maximum number of fatalities so as to look for safety measures of the passengers accordingly. I would also like to know about the reason which caused the most of these accidents and which airlines were responsible for the same.

# %%
#initial dataset
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
file='/Users/jusnoorkaursachdeva/Desktop/school/year1/summer/cosc301/project-group46/data/processed/COSC301_dataset - Sheet1.csv'
data=pd.read_csv(file)
data
# Out:
#                                                  date   time  \
# 0                                          01/03/2004   4:44
# 1                                          01/13/2004  19:40
# 2                                          01/17/2004  16:40
# 3                                          01/28/2004  20:55
# 4                                          02/06/2004   8:01
# ..                                                ...    ...
# 599                                        05/26/2009    NaN
# 600                                        06/01/2009   0:15
# 601                                        06/07/2009   8:30
# 602  >>>>>>> ea9cce248f81730041f8858938a0313971237052    NaN
# 603                                        06/08/2009    NaN
#
#                                               Location  \
# 0                           Off Sharm el Sheikh, Egypt
# 1                                 Tashkent, Uzbekistan
# 2         Lake Erie, off Pelee Island, Ontario, Canada
# ...

# %%
data_final = data.copy().drop(['registeration', 'Ground','time' ], axis=1)
print("This is the dataset after removing all the unwanted columns : ")
data_final
# Out:
# This is the final datset to answer my research question :
#                                                  date  \
# 0                                          01/03/2004
# 1                                          01/13/2004
# 2                                          01/17/2004
# 3                                          01/28/2004
# 4                                          02/06/2004
# ..                                                ...
# 599                                        05/26/2009
# 600                                        06/01/2009
# 601                                        06/07/2009
# 602  >>>>>>> ea9cce248f81730041f8858938a0313971237052
# 603                                        06/08/2009
#
#                                               Location  \
# 0                           Off Sharm el Sheikh, Egypt
# 1                                 Tashkent, Uzbekistan
# 2         Lake Erie, off Pelee Island, Ontario, Canada
# ...

# %%
#removing null values and duplicates
import project_functions1 as pf 
file='/Users/jusnoorkaursachdeva/Desktop/school/year1/summer/cosc301/project-group46/data/processed/COSC301_dataset - Sheet1.csv'
data_2 = pf.data_clean(file)
data_2
# Out:
#            date   time                                           Location  \
# 0    01/03/2004   4:44                         Off Sharm el Sheikh, Egypt
# 1    01/13/2004  19:40                               Tashkent, Uzbekistan
# 2    01/17/2004  16:40       Lake Erie, off Pelee Island, Ontario, Canada
# 3    01/28/2004  20:55                                  Ghardaïa, Algeria
# 4    02/06/2004   8:01                        Bitonja, Bosnia-Herzegovina
# ..          ...    ...                                                ...
# 295  05/03/2009  12:00                   Near El Alto de Rubio, Venezuela
# 296  05/20/2009   6:30                             Near Madiun, Indonesia
# 298  06/01/2009   0:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 299  06/07/2009   8:30       Near Port Hope Simpson, Newfoundland, Canada
# 301        date   time                                           Location
#
#                                Operator  \
# ...

# %%
#finding which arline caused the maximum number of deaths/fatalities
import project_functions1 as pf 
file='/Users/jusnoorkaursachdeva/Desktop/school/year1/summer/cosc301/project-group46/data/processed/COSC301_dataset - Sheet1.csv'
data_2 = pf.data_clean(file)
deaths_max = data_2.groupby('Operator')[['Fatilities']].sum() 
deaths_max = deaths_max.sort_values(by='Fatilities', ascending =False)
deaths_max
# Out:
#                                            Fatilities
# Operator
# Operator                                   Fatilities
# Mandala Airlines                                   99
# ADC Airlines                                       96
# Military - IslamiRepubliof Iran Air Force          94
# One-Two-Go Airlines                                90
# ...                                               ...
# Regional Compagnie Aerienne Europeenne              0
# Southwest Airlines                                  0
# British Airways                                     0
# Centurian Air Cargo                                 0
# US Airways                                          0
#
# [249 rows x 1 columns]

# %%
#now we can use the above displayed death_max data to find top 5 airlines causing maximum fatalities and plot the same 
import project_functions1 as pf 
file='/Users/jusnoorkaursachdeva/Desktop/school/year1/summer/cosc301/project-group46/data/processed/COSC301_dataset - Sheet1.csv'
data_2 = pf.data_clean(file)
deaths_max = data_2.groupby('Operator')[['Fatilities']].sum() 
deaths_max = deaths_max.sort_values(by='Fatilities', ascending =False)
deaths_max5 = deaths_max.head(6)  #6 because this will let us get 5 values for the plotting on the graph
# Out:
#                                            Fatilities
# Operator
# Operator                                   Fatilities
# Mandala Airlines                                   99
# ADC Airlines                                       96
# Military - IslamiRepubliof Iran Air Force          94
# One-Two-Go Airlines                                90
# Turkish Airlines                                    9

# %%
import project_functions1 as pf 
file='/Users/jusnoorkaursachdeva/Desktop/school/year1/summer/cosc301/project-group46/data/processed/COSC301_dataset - Sheet1.csv'
data_2 = pf.data_clean(file)
deaths_max = data_2.groupby('Operator')[['Fatilities']].sum() 
deaths_max = deaths_max.sort_values(by='Fatilities', ascending =False)
deaths_max20 = deaths_max.head(20)  
print("displaying the top 20 airlines causing maximum fatalities: ")
deaths_max20
# Out:
# displaying the top 20 airlines causing maximum fatalities:
#                                            Fatilities
# Operator
# Operator                                   Fatilities
# Mandala Airlines                                   99
# ADC Airlines                                       96
# Military - IslamiRepubliof Iran Air Force          94
# One-Two-Go Airlines                                90
# Turkish Airlines                                    9
# Junction City Fire Department                       9
# Military - French Air Force                         9
# Military - Government of Macedonia                  9
# Atran                                               9
# Military - U.S. Air Force                           9
# Tura Air Enterprise                                 9
# Moskovia Airlines                                   9
# Aerocord                                            9
# Aeroflot                                           88
# ...

# %%
#just to analyse about the maximum number of fatalities caused by the top 20 airlines/operators 
import seaborn as sns
sns.jointplot(data=deaths_max20,x='Fatilities',y='Operator',height=20)

# %% [markdown]
# we get to know after looking at the data that west carribean airlines caused the maximum number of fatalities/deaths

# %%
#looking for models that crashed the most so grouping the type anf fatalities together
type_deaths = data_2.groupby('type')[['Fatilities']].sum()
type_deaths

#now looking for the top 5 values of deaths caused by the different airlines
type_deaths_5 = type_deaths.sort_values(by='Fatilities')
type_deaths_5 = type_deaths.head(6) 
type_deaths_5
# Out:
#                                  Fatilities
# type
# ATR-42-300                               46
# ATR-72-202                               16
# Aerospatiale AS-350BA                     4
# Aerospatiale AS350BA Rotocraft            4
# Aerospatiale SA365N-1 Dauphin II          4
# Airbus A-310-324                         32

# %%
#plotting the above extracted data into a graph for a thorough analysis and conclude a result
graph_type_deaths= sns.displot(type_deaths_5, x="Fatilities",y=type_deaths_5.index,aspect=3)

# %% [markdown]
# According to the data that i have extracted above by ffinding the top 5 types that caused the maximum number of deaths/fatalities, we get that the maximum number of fatalities were caused by airbus ATR-42-300 which is 46.
